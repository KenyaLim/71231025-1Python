# %%
#SOAL 1

# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10)
y = np.sin(x)
z = np.cos(x)

plt.plot(x,y,'b',x,z,'r')
plt.xlabel('Radians');
plt.ylabel('Value');
plt.title('Plotting Demonstration')
plt.legend(['Sin','Cos'])
plt.grid
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <function matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)>

# %%
#SOAL 2

j = 0
while j < 2:
    gram = int(input("Jumlah gram = "))
    hb = int(input("Harga emas yang dibeli = "))
    hb2 = int(input("Harga emas naik menjadi = "))
    profit = hb2 - hb
    profitpersen = (profit  / hb) * 100
    
print(profit)
print(profitpersen)
# Out:
# Jumlah gram = 25
# Harga emas yang dibeli = 650000
# Harga emas naik menjadi = 685000
# Jumlah gram = 15
# Harga emas yang dibeli = 685000
# Harga emas naik menjadi = 715000

# %%
#SOAL 3.

uang = float(input("Masukkan saldo awal = "))
akhir = int(input("Masukkan saldo akhir yang ingin dicapai = "))
bunga = float(input("BUNGA = "))

yr = 0
while uang<akhir :
    t = float ( uang *bunga/100)
    uang+=t
    yr += 1
    
print(yr)
print(uang)
# Out:
# Masukkan saldo awal = 200
# Masukkan saldo akhir yang ingin dicapai = 400
# BUNGA = 10
# 8
# 428.71776199999994
